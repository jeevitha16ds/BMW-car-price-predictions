# %% [markdown]
# ## **Import basic libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **read file**

# %%
data=pd.read_csv("bmw.csv")
data.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6         2.0
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8         2.0
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4         3.0
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4         1.5
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4         3.0

# %%
data.shape
# Out:
# (10781, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
data.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
missing=data.isnull().sum().sort_values(ascending=False)
missing[missing>0]
# Out:
# Series([], dtype: int64)

# %%
data.shape
# Out:
# (10781, 9)

# %%
cat=data.select_dtypes(include="object")
cat.columns
# Out:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
num=data.select_dtypes(include=["int64","float64"])
num.columns
# Out:
# Index(['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')

# %%
for x in cat.columns:
  print(x)
  print("unique values are")
  print(data[x].unique())
  print("no of unique values",data[x].nunique())
  print("value counts")
  print(data[x].value_counts())
  print()
# Out:
# model
# unique values are
# [' 5 Series' ' 6 Series' ' 1 Series' ' 7 Series' ' 2 Series' ' 4 Series'
#  ' X3' ' 3 Series' ' X5' ' X4' ' i3' ' X1' ' M4' ' X2' ' X6' ' 8 Series'
#  ' Z4' ' X7' ' M5' ' i8' ' M2' ' M3' ' M6' ' Z3']
# no of unique values 24
# value counts
#  3 Series    2443
#  1 Series    1969
#  2 Series    1229
#  5 Series    1056
#  4 Series     995
#  X1           804
#  X3           551
#  X5           468
#  X2           288
#  X4           179
#  M4           125
#  Z4           108
#  6 Series     108
#  7 Series     106
#  X6           106
#  X7            55
#  i3            43
#  8 Series      39
#  M5            29
#  M3            27
#  M2            21
#  i8            17
#  M6             8
#  Z3             7
# Name: model, dtype: int64
#
# transmission
# unique values are
# ['Automatic' 'Manual' 'Semi-Auto']
# no of unique values 3
# value counts
# Semi-Auto    4666
# Automatic    3588
# Manual       2527
# Name: transmission, dtype: int64
#
# fuelType
# unique values are
# ['Diesel' 'Petrol' 'Other' 'Hybrid' 'Electric']
# no of unique values 5
# value counts
# Diesel      7027
# Petrol      3417
# Hybrid       298
# Other         36
# Electric       3
# Name: fuelType, dtype: int64

# %%
for x in num.columns:
  print(x)
  print("unique values are")
  print(data[x].unique())
  print("no of unique values",data[x].nunique())
  print("value counts")
  print(data[x].value_counts())
  print()
# Out:
# year
# unique values are
# [2014 2018 2016 2017 2015 2019 2013 2020 2002 2004 2007 2008 2011 2012
#  2009 2006 2010 2003 2001 2005 2000 1999 1996 1997 1998]
# no of unique values 25
# value counts
# 2019    3485
# 2016    1882
# 2017    1721
# 2015     922
# 2018     848
# 2020     733
# 2014     501
# 2013     357
# 2012     119
# 2011      51
# 2010      41
# 2009      30
# 2008      23
# 2007      16
# 2006      14
# 2004      12
# 2005       6
# 2002       6
# 1999       4
# 2001       3
# 2000       2
# 2003       2
# 1997       1
# 1998       1
# 1996       1
# Name: year, dtype: int64
#
# price
# unique values are
# [11200 27000 16000 ... 18887  5678  9930]
# no of unique values 3777
# value counts
# 20980    45
# 15000    43
# 14000    40
# 18000    37
# 29995    36
#          ..
# 5678      1
# 19997     1
# 42520     1
# 19989     1
# 32748     1
# Name: price, Length: 3777, dtype: int64
#
# mileage
# unique values are
# [67068 14827 62794 ... 40818 25468 59432]
# no of unique values 8086
# value counts
# 123      151
# 10       149
# 101       80
# 1000      69
# 5000      60
#         ...
# 397        1
# 4495       1
# 27024      1
# 58436      1
# 33301      1
# Name: mileage, Length: 8086, dtype: int64
#
# tax
# unique values are
# [125 145 160  30  20 135   0 165 200 150 205 300 140 235 260 305 265 555
#  325 570 240 565 330 110 195 185 120 540 315 155 190 250 245 255 270 580
#  130 280]
# no of unique values 38
# value counts
# 145    5372
# 150    1241
# 30      989
# 125     844
# 20      485
# 160     432
# 0       340
# 200     337
# 165     118
# 135     117
# 205      98
# 300      84
# 235      71
# 260      60
# 140      36
# 325      26
# 305      25
# 555      17
# 265      14
# 240      13
# 570      12
# 330      12
# 565       9
# 270       5
# 120       4
# 315       3
# 195       3
# 245       2
# 190       2
# 580       2
# 280       1
# 540       1
# 110       1
# 185       1
# 130       1
# 250       1
# 155       1
# 255       1
# Name: tax, dtype: int64
#
# mpg
# unique values are
# [ 57.6  42.8  51.4  72.4  50.4  60.1  52.3  62.8  68.9  54.3  58.9 148.7
#   64.2  70.6  83.1  67.3  53.3  47.9  65.7 470.8  39.8 141.2  61.4  37.2
#   47.1  43.5  48.7  34.   55.4  49.6  74.3  85.6 134.5  44.8  55.5  46.3
#   44.1  37.7 113.   35.3  78.5  36.2  41.5  31.4  39.2  24.8  34.5  42.2
#   32.5  40.9  38.2  56.5  45.6  57.7  24.1  33.6  40.4  36.7  35.8  26.9
#  156.9  26.7  24.4  38.7  29.1  33.2 135.5  28.5  32.1  27.4   5.5  30.4
#   26.4  34.9  27.2  25.4  31.    8.8  31.7 188.3  32.8 128.4  23.2  23.7
#   29.7  30.1  28.8  22.8  23.3 141.3  34.4  29.4  19.1  24.6  27.7  25.2
#   22.1  30.7  21.9  26.6  22.6  20.8]
# no of unique values 102
# value counts
# 65.7     684
# 60.1     591
# 62.8     575
# 54.3     497
# 50.4     442
#         ...
# 20.8       1
# 128.4      1
# 26.6       1
# 23.2       1
# 22.6       1
# Name: mpg, Length: 102, dtype: int64
#
# engineSize
# unique values are
# [2.  3.  1.5 0.6 1.6 4.4 0.  2.2 2.5 4.  3.2 1.  5.  1.9 6.6 2.8 3.5]
# no of unique values 17
# value counts
# 2.0    6575
# 3.0    2458
# 1.5    1463
# 1.6     109
# 4.4      79
# 0.0      47
# 2.5      14
# 0.6       7
# 4.0       6
# 2.2       6
# 3.2       5
# 1.9       5
# 6.6       2
# 2.8       2
# 1.0       1
# 5.0       1
# 3.5       1
# Name: engineSize, dtype: int64

# %% [markdown]
# # **Exploratory data Analysis**

# %%
cat=data.select_dtypes(include="object")
L=[3,1,1]
a,b,c=L
fig=plt.figure(figsize=(8,15))
for x in cat:
  plt.subplot(a,b,c)
  sns.countplot(data[x])
 
  
  c=c+1

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[10,4,1]
a,b,c=L
fig=plt.figure(figsize=(20,35))
for x in num:
  plt.subplot(a,b,c)
  sns.distplot(data[x],color="green")
  
  c=c+1

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[6,3,1]
a,b,c=L
fig=plt.figure(figsize=(25,25))
for x in num:
  plt.subplot(a,b,c)
  sns.boxplot(data[x],color="gold")
  
  c=c+1

# %%
cat=data.select_dtypes(include="object")
L=[3,2,1]
a,b,c=L
fig=plt.figure(figsize=(15,15))
for x in cat:
  plt.subplot(a,b,c)
  sns.barplot(data[x],data["price"])
  x=plt.xticks(rotation=90)
 
  
  c=c+1

# %%
cat=data.select_dtypes(include="object")
L=[20,2,1]
a,b,c=L
fig=plt.figure(figsize=(14,150))

for x in cat:
  plt.subplot(a,b,c)
  sns.boxplot(data[x],data["price"])
  x=plt.xticks(rotation=90)
  c=c+1

# %%
cat=data.select_dtypes(include="object")
L=[20,2,1]
a,b,c=L
fig=plt.figure(figsize=(35,90))
for x in cat:
  plt.subplot(a,b,c)
  sns.violinplot(data[x],data["price"])
  
  c=c+1

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[15,3,1]
a,b,c=L
fig=plt.figure(figsize=(20,60))
for x in num:
  plt.subplot(a,b,c)
  sns.scatterplot(data[x],data['price'],color="brown")
  
  c=c+1

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[15,3,1]
a,b,c=L
fig=plt.figure(figsize=(20,60))
for x in num:
  plt.subplot(a,b,c)
  sns.scatterplot(data[x],data['price'],hue=data["mileage"])
  
  c=c+1

# %%
A=[]
for x in data:
  A.append(x)
print(A)
import random
random.shuffle(A)
print(A)
# Out:
# ['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg', 'engineSize']
# ['price', 'engineSize', 'transmission', 'mpg', 'year', 'fuelType', 'mileage', 'tax', 'model']

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[15,3,1]
a,b,c=L
fig=plt.figure(figsize=(20,70))
for x,y in zip(num,A):
  plt.subplot(a,b,c)
  sns.scatterplot(data[x],data[y],color="red",edgecolor="k")
  
  c=c+1

# %%
data.describe().T
# Out:
#               count          mean           std  ...      50%      75%       max
# year        10781.0   2017.078935      2.349038  ...   2017.0   2019.0    2020.0
# price       10781.0  22733.408867  11415.528189  ...  20462.0  27940.0  123456.0
# mileage     10781.0  25496.986550  25143.192559  ...  18347.0  38206.0  214000.0
# tax         10781.0    131.702068     61.510755  ...    145.0    145.0     580.0
# mpg         10781.0     56.399035     31.336958  ...     53.3     62.8     470.8
# engineSize  10781.0      2.167767      0.552054  ...      2.0      2.0       6.6
#
# [6 rows x 8 columns]

# %%
sns.distplot(data['price'],color="cyan")

# %%
data.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.623756 -0.774382  0.025200 -0.071762   -0.026337
# price       0.623756  1.000000 -0.605397  0.263484 -0.204882    0.460196
# mileage    -0.774382 -0.605397  1.000000 -0.170747  0.118609   -0.002540
# tax         0.025200  0.263484 -0.170747  1.000000 -0.351798    0.429616
# mpg        -0.071762 -0.204882  0.118609 -0.351798  1.000000   -0.399844
# engineSize -0.026337  0.460196 -0.002540  0.429616 -0.399844    1.000000

# %%
# plotting Heat map
corr=data.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corr ,cmap="YlGnBu",annot=True)

# %%
#Trying to find the columns which has more correlation greater than 0.5 with saleprice.
num_data_corr=num.corr()['price'][:-1]
good_corr_fea_list=num_data_corr[abs(num_data_corr)>0.25].sort_values(ascending=False)
print("There are {} strongly correlated values with Saleprice:\n{}".format(len(good_corr_fea_list),good_corr_fea_list))
# Out:
# There are 4 strongly correlated values with Saleprice:
# price      1.000000
# year       0.623756
# tax        0.263484
# mileage   -0.605397
# Name: price, dtype: float64

# %%
#Feature to Feature Relationships using heatmap
fea_corr=num.drop('price',axis=1).corr()
plt.subplots(figsize=(12,14))
sns.heatmap(fea_corr[(fea_corr>=0.5)|(fea_corr<=-0.4)],
              cmap='viridis',vmax=1.0,vmin=-1.0, linewidths= 0.4,
                 annot=True,annot_kws={"size":8},square=True) ;

# %%
#sns.pairplot(data)

# %%
for i in num:
  Q25=data[i].quantile(0.25)
  Q75=data[i].quantile(0.75)
  IQR=Q75-Q25
  min_limit=Q25-1.5*IQR
  max_limit=Q75+1.5*IQR
  outliers1=[x for x in data[i] if x < min_limit or x > max_limit]
  median=np.median(data[i])
  data[i]=data[i].replace(outliers1,max_limit)

# %%
num=data.select_dtypes(include=["int64","float64"])
L=[13,3,1]
a,b,c=L
fig=plt.figure(figsize=(25,45))
for x in num:
  plt.subplot(a,b,c)
  sns.boxplot(data[x],color="violet")
  
  c=c+1

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
cat_data=data.select_dtypes(include='object')
for x in cat_data:
  data[x]=label.fit_transform(data[x].astype(str))

# %%
data.head()
# Out:
#    model    year  price  transmission  mileage  fuelType  tax   mpg  engineSize
# 0      4  2014.0  11200             0  67068.0         0  125  57.6         2.0
# 1      5  2018.0  27000             0  14827.0         4  145  42.8         2.0
# 2      4  2016.0  16000             0  62794.0         0  160  51.4         2.0
# 3      0  2017.0  12750             0  26676.0         0  145  72.4         2.0
# 4      6  2014.0  14500             0  39554.0         0  160  50.4         2.0

# %%
x=data.drop('price',axis=1)
y=data[["price"]]

# %%
from sklearn.preprocessing  import StandardScaler
model=StandardScaler()
print(model.fit(x))
x_transform=model.transform(x)
print(x_transform)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [[-0.21436266 -1.61170092 -1.26543763 ... -2.44120673  0.29339089
#    0.        ]
#  [-0.04919372  0.29288195 -1.26543763 ... -0.3438107  -0.87776517
#    0.        ]
#  [-0.21436266 -0.65940949 -1.26543763 ...  1.22923632 -0.19722854
#    0.        ]
#  ...
#  [-0.54470056 -0.18326377 -0.11503008 ...  1.22923632 -0.87776517
#    0.        ]
#  [-0.87503845 -1.61170092 -1.26543763 ...  1.22923632  0.81566319
#    0.        ]
#  [ 1.27215785 -0.18326377 -1.26543763 ... -2.44120673  0.29339089
#    0.        ]]

# %%
scaled_x_fea=pd.DataFrame(x_transform, columns = x.columns)
scaled_x_fea.head()
# Out:
#       model      year  transmission  ...       tax       mpg  engineSize
# 0 -0.214363 -1.611701     -1.265438  ... -2.441207  0.293391         0.0
# 1 -0.049194  0.292882     -1.265438  ... -0.343811 -0.877765         0.0
# 2 -0.214363 -0.659409     -1.265438  ...  1.229236 -0.197229         0.0
# 3 -0.875038 -0.183264     -1.265438  ... -0.343811  1.464547         0.0
# 4  0.115975 -1.611701     -1.265438  ...  1.229236 -0.276361         0.0
#
# [5 rows x 8 columns]

# %%
log_transform_y=np.log(y)
log_transform_y.head()
# Out:
#        price
# 0   9.323669
# 1  10.203592
# 2   9.680344
# 3   9.453287
# 4   9.581904

# %%
#Lasso method to select features
from sklearn .linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
feature_selection=SelectFromModel(Lasso(alpha=0.005,random_state=1))
feature_selection.fit(scaled_x_fea,log_transform_y)
feature_selection.get_support()
selected=scaled_x_fea.columns[(feature_selection.get_support())]
print('Total features:{}'.format(scaled_x_fea.shape[1]))
print('Selected features:{}'.format(len(selected)))
selected
x_sel_features=x[selected]
x_sel_features.shape
new_data=x_sel_features.join(log_transform_y)
new_data.head()
# Out:
# Total features:8
# Selected features:7
#    model    year  transmission  mileage  fuelType  tax   mpg      price
# 0      4  2014.0             0  67068.0         0  125  57.6   9.323669
# 1      5  2018.0             0  14827.0         4  145  42.8  10.203592
# 2      4  2016.0             0  62794.0         0  160  51.4   9.680344
# 3      0  2017.0             0  26676.0         0  145  72.4   9.453287
# 4      6  2014.0             0  39554.0         0  160  50.4   9.581904

# %%
X=new_data.drop('price',axis=1)
Y=new_data["price"]

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
selection=ExtraTreesRegressor()
selection.fit(X,Y)
print(selection.feature_importances_)
plt.figure(figsize=(12,8))
fea_importances=pd.Series(selection.feature_importances_,index=X.columns)
fea_importances.nlargest(39).plot(kind='barh')
plt.show()
# Out:
# [0.16796111 0.22043708 0.05022489 0.40692051 0.01879521 0.04152377
#  0.09413743]

# %%
#train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,
                                    test_size=0.33,random_state=200)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7223, 7), (3558, 7), (7223,), (3558,))

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
#fit the model and predict values
linear.fit(X_train, y_train)
y_predict = linear.predict(X_test)
#print(y_predict)
#Print the intercept and coefficient of x_features
print('The intercept is {}'.format(linear.intercept_))
pd.DataFrame(linear.coef_,X.columns,columns=['Coefficient'])
# Out:
# The intercept is -6.575789847276997
#               Coefficient
# model            0.020775
# year             0.008621
# transmission     0.007525
# mileage         -0.000013
# fuelType        -0.038539
# tax             -0.001246
# mpg             -0.008551

# %%
#Evaluating the linear model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,y_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,y_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.06214066083170515
# MAE:0.18277435353773933
# RMSE:0.2492802856860228

# %%
import statsmodels.api as sm
x_1=sm.add_constant(y_predict)#y=mx+c  
model=sm.OLS(y_test,x_1)#initialised the model
linear=model.fit()
print('r2_score of linear model is {}'.format(linear.rsquared))
print('adjr2_score of linear model is {}'.format(linear.rsquared_adj))
# Out:
# r2_score of linear model is 0.7126002822944454
# adjr2_score of linear model is 0.7125194612264742

# %%
#Ridge
from sklearn.linear_model import  Ridge
ridge = Ridge()
#fit the model and predict values
ridge.fit(X_train, y_train)
ridge_predict = ridge.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,ridge_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,ridge_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.06214064578218141
# MAE:0.1827748183627355
# RMSE:0.24928025550007246

# %%
import statsmodels.api as sm
x_1=sm.add_constant(ridge_predict)
model=sm.OLS(y_test,x_1)#initialised the model
ridge=model.fit()
print('r2_score of Ridge model is {}'.format(ridge.rsquared))
print('adjr2_score of Ridge model is {}'.format(ridge.rsquared_adj))
# Out:
# r2_score of Ridge model is 0.7126003322513689
# adjr2_score of Ridge model is 0.7125195111974463

# %%
#LASSO
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train, y_train)
lasso_predict = lasso.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,lasso_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,lasso_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.08869704359656579
# MAE:0.2298618701289188
# RMSE:0.2978204888797374

# %%
import statsmodels.api as sm
x_1=sm.add_constant(lasso_predict)
model=sm.OLS(y_test,x_1)#initialised the model
lasso=model.fit()
print('r2_score of Lasso model is {}'.format(lasso.rsquared))
print('adjr2_score of Lasso model is {}'.format(lasso.rsquared_adj))
# Out:
# r2_score of Lasso model is 0.5898101944609684
# adjr2_score of Lasso model is 0.5896948429970935

# %%
#Kernel Ridge
from sklearn.kernel_ridge import KernelRidge
kr = KernelRidge()
kr.fit(X_train, y_train)
kr_predict = kr.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,kr_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,kr_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.06216004743288313
# MAE:0.18348245506270017
# RMSE:0.24931916780079932

# %%
import statsmodels.api as sm
x_1=sm.add_constant(kr_predict)
model=sm.OLS(y_test,x_1)#initialised the model
kr=model.fit()
print('r2_score of Kernel ridge model is {}'.format(kr.rsquared))
print('adjr2_score of Kernel Ridge model is {}'.format(kr.rsquared_adj))
# Out:
# r2_score of Kernel ridge model is 0.712507668973684
# adjr2_score of Kernel Ridge model is 0.7124268218614719

# %%
#Elastic Net
from sklearn.linear_model import  ElasticNet
en = ElasticNet()
en.fit(X_train, y_train)
en_predict = en.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,en_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,en_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.0718948413194685
# MAE:0.20631450066305695
# RMSE:0.2681321340672701

# %%
import statsmodels.api as sm
x_1=sm.add_constant(en_predict)
model=sm.OLS(y_test,x_1)#initialised the model
en=model.fit()
print('r2_score of elastic net model is {}'.format(en.rsquared))
print('adjr2_score elastic net model is {}'.format(en.rsquared_adj))
# Out:
# r2_score of elastic net model is 0.6690911206191981
# adjr2_score elastic net model is 0.6689980641289335

# %%
#Support Vector machine
from sklearn.svm import SVR
svm = SVR()
svm.fit(X_train, y_train)
svm_predict = svm.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,svm_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,svm_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.08776237940161048
# MAE:0.226241912954488
# RMSE:0.2962471593139932

# %%
import statsmodels.api as sm
x_1=sm.add_constant(svm_predict)
model=sm.OLS(y_test,x_1)#initialised the model
svm=model.fit()
print('r2_score of svm model is {}'.format(svm.rsquared))
print('adjr2_score of svm model is {}'.format(svm.rsquared_adj))
# Out:
# r2_score of svm model is 0.5959535728715435
# adjr2_score of svm model is 0.5958399490168955

# %%
#KNN
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
knn_predict = knn.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,knn_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,knn_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.08305854926587188
# MAE:0.22052755989191447
# RMSE:0.28819880163850764

# %%
import statsmodels.api as sm
x_1=sm.add_constant(knn_predict)
model=sm.OLS(y_test,x_1)#initialised the model
knn=model.fit()
print('r2_score of KNN model is {}'.format(knn.rsquared))
print('adjr2_score of KNN model is {}'.format(knn.rsquared_adj))
# Out:
# r2_score of KNN model is 0.6193699180696531
# adjr2_score of KNN model is 0.6192628792389641

# %%
#DECISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
dt_predict = dt.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,dt_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,dt_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.024745407130247185
# MAE:0.09863287583038811
# RMSE:0.1573067294499736

# %%
import statsmodels.api as sm
x_1=sm.add_constant(dt_predict)
model=sm.OLS(y_test,x_1)#initialised the model
dt=model.fit()
print('r2_score of Decision tree model  is {}'.format(dt.rsquared))
print('adjr2_score of Decision tree model is  {}'.format(dt.rsquared_adj))
# Out:
# r2_score of Decision tree model  is 0.8902092758946281
# adjr2_score of Decision tree model is  0.8901784011128212

# %%
#XGB
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
xgb_predict = xgb.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,xgb_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,xgb_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# [17:59:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE:0.015712711395938894
# MAE:0.08787828667215349
# RMSE:0.1253503545903995

# %%
import statsmodels.api as sm
x_1=sm.add_constant(xgb_predict)
model=sm.OLS(y_test,x_1)#initialised the model
xgb=model.fit()
print('r2_score of XGB model is {}'.format(xgb.rsquared))
print('adjr2_score XGB model is {}'.format(xgb.rsquared_adj))
# Out:
# r2_score of XGB model is 0.9275664213939351
# adjr2_score XGB model is 0.9275460519961268

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
rf =  RandomForestRegressor()
rf.fit(X_train, y_train)
rf_predict = rf.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,rf_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,rf_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.013702093107331358
# MAE:0.07394347114905098
# RMSE:0.11705594007709032

# %%
import statsmodels.api as sm
x_1=sm.add_constant(rf_predict)
model=sm.OLS(y_test,x_1)#initialised the model
rf=model.fit()
print('r2_score of Random forest model  is {}'.format(rf.rsquared))
print('adjr2_score of Random forest model is {}'.format(rf.rsquared_adj))
# Out:
# r2_score of Random forest model  is 0.9366256746073415
# adjr2_score of Random forest model is 0.93660785280605

# %%
#GradientBoostingRegressor
from sklearn.ensemble import  GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)
gb_predict = gb.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,gb_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,gb_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.015909416513237615
# MAE:0.08787501426920133
# RMSE:0.12613253550625872

# %%
import statsmodels.api as sm
x_1=sm.add_constant(gb_predict)
model=sm.OLS(y_test,x_1)#initialised the model
gb=model.fit()
print('r2_score of GradientBoostingRegressor is {}'.format(gb.rsquared))
print('adjr2_score of GradientBoostingRegressor is {}'.format(gb.rsquared_adj))
# Out:
# r2_score of GradientBoostingRegressor is 0.9265501464331539
# adjr2_score of GradientBoostingRegressor is 0.926529491243737

# %%
#AdaBoostRegressor
from sklearn.ensemble import  AdaBoostRegressor
ab = AdaBoostRegressor()
ab.fit(X_train, y_train)
ab_predict = ab.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,ab_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,ab_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.045601949695426705
# MAE:0.16758695436063123
# RMSE:0.21354613013451382

# %%
import statsmodels.api as sm
x_1=sm.add_constant(ab_predict)
model=sm.OLS(y_test,x_1)#initialised the model
ab=model.fit()
print('r2_score of AdaBoostRegressor is {}'.format(ab.rsquared))
print('adjr2_score of AdaBoostRegressor is {}'.format(ab.rsquared_adj))
# Out:
# r2_score of AdaBoostRegressor is 0.8051866994633461
# adjr2_score of AdaBoostRegressor is 0.8051319150706193

# %%
# LGBMRegressor
from lightgbm import LGBMRegressor
lgb = LGBMRegressor()
lgb.fit(X_train, y_train)
lgb_predict = lgb.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,lgb_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,lgb_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.013415225340501514
# MAE:0.07504540048815363
# RMSE:0.11582411381271826

# %%
import statsmodels.api as sm
x_1=sm.add_constant(lgb_predict)
model=sm.OLS(y_test,x_1)#initialised the model
lgb=model.fit()
print('r2_score of  LGBMRegressor is {}'.format(lgb.rsquared))
print('adjr2_score of  LGBMRegressor is {}'.format(lgb.rsquared_adj))
# Out:
# r2_score of  LGBMRegressor is 0.9379444509214174
# adjr2_score of  LGBMRegressor is 0.9379269999796068

# %%
#ExtraTreesRegressor
from sklearn.ensemble import  ExtraTreesRegressor
et = ExtraTreesRegressor()
et.fit(X_train, y_train)
et_predict = et.predict(X_test)
#y_predict
#Evaluating the model using MSE,MAE,RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE=mean_squared_error(y_test,et_predict)
print('MSE:{}'.format(MSE))
MAE=mean_absolute_error(y_test,et_predict)
print('MAE:{}'.format(MAE))
RMSE=np.sqrt(MSE)
print('RMSE:{}'.format(RMSE))
# Out:
# MSE:0.013589183592751668
# MAE:0.07386012317718751
# RMSE:0.11657265370897099

# %%
import statsmodels.api as sm
x_1=sm.add_constant(et_predict)
model=sm.OLS(y_test,x_1)#initialised the model
et=model.fit()
print('r2_score of ExtraTreesRegressor is {}'.format(et.rsquared))
print('adjr2_score of ExtraTreesRegressor is {}'.format(et.rsquared_adj))
# Out:
# r2_score of ExtraTreesRegressor is 0.9372086738372833
# adjr2_score of ExtraTreesRegressor is 0.9371910159840318

# %%
models=[linear,ridge,lasso,kr,en,svm,knn,rf,dt,gb,xgb,ab,et,lgb]
A=['linear','ridge','lasso','kr','en','svm','knn','rf','dt','gb','xgb','ab','et','lgb']
for x,y in zip(models,A):
  print('r2_score of {} model is {}'.format(y,x.rsquared))
# Out:
# r2_score of linear model is 0.7126002822944454
# r2_score of ridge model is 0.7126003322513689
# r2_score of lasso model is 0.5898101944609684
# r2_score of kr model is 0.712507668973684
# r2_score of en model is 0.6690911206191981
# r2_score of svm model is 0.5959535728715435
# r2_score of knn model is 0.6193699180696531
# r2_score of rf model is 0.9366256746073415
# r2_score of dt model is 0.8902092758946281
# r2_score of gb model is 0.9265501464331539
# r2_score of xgb model is 0.9275664213939351
# r2_score of ab model is 0.8051866994633461
# r2_score of et model is 0.9372086738372833
# r2_score of lgb model is 0.9379444509214174

# %%
for x,y in zip(models,A):
  z=np.round(x.rsquared,4)
  print(y,z)
# Out:
# linear 0.7126
# ridge 0.7126
# lasso 0.5898
# kr 0.7125
# en 0.6691
# svm 0.596
# knn 0.6194
# rf 0.9366
# dt 0.8902
# gb 0.9266
# xgb 0.9276
# ab 0.8052
# et 0.9372
# lgb 0.9379

# %%
optimized_scores = pd.DataFrame({'Optimized Scores':np.round([linear.rsquared, ridge.rsquared,svm.rsquared,knn.rsquared,rf.rsquared,dt.rsquared,gb.rsquared,xgb.rsquared,et.rsquared,lgb.rsquared,ab.rsquared], 4)})
optimized_scores.index = ['Linear','ridge','svm','knn','rf','dt','gb','xgb','et','lgb','ab']
optimized_scores.sort_values(by = 'Optimized Scores')
# Out:
#         Optimized Scores
# svm               0.5960
# knn               0.6194
# Linear            0.7126
# ridge             0.7126
# ab                0.8052
# dt                0.8902
# gb                0.9266
# xgb               0.9276
# rf                0.9366
# et                0.9372
# lgb               0.9379
